# %% [markdown]
# <a href="https://colab.research.google.com/github/makarovt/iskcf-beacon/blob/main/Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# игрушечная "трафик-модель" ISKCF
def causal_step(x, k=0.3): return x + k*(1 - x**2)
xs = [0.1]
for _ in range(50): xs.append(causal_step(xs[-1]))
xs[-10:]
